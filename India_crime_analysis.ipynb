# %%
import pandas as pd 
import pandas as pd
df_keys = pd.read_csv("Desktop/7042/7042_KEYS.csv")
df_metadata = pd.read_csv("Desktop/7042/7042_METADATA.csv")
df_source_data = pd.read_csv("Desktop/7042/7042_source_data.csv")
df_Ndap_report = pd.read_csv("Desktop/7042/NDAP_REPORT_7042.csv")

# %%
df_keys.head()
# Out:
#        srcStateName  srcYear Country  StateCode          StateName
# 0   Jammu & Kashmir     2016   India          1  JAMMU AND KASHMIR  \
# 1   Jammu & Kashmir     2017   India          1  JAMMU AND KASHMIR
# 2   Jammu & Kashmir     2018   India          1  JAMMU AND KASHMIR
# 3  Himachal Pradesh     2016   India          2   HIMACHAL PRADESH
# 4  Himachal Pradesh     2017   India          2   HIMACHAL PRADESH
#
#    TotalPopulation  TotalPopulationUrban  TotalPopulationRural
# 0         12267013               3371233               8895780  \
# 1         12267013               3371233               8895780
# 2         12267013               3371233               8895780
# 3          6864602                688552               6176050
# 4          6864602                688552               6176050
#
#    TotalPopulationMale  TotalPopulationMaleUrban  ...
# 0              6483906                   1825543  ...  \
# 1              6483906                   1825543  ...
# ...

# %%
df_keys.columns
# Out:
# Index(['srcStateName', 'srcYear', 'Country', 'StateCode', 'StateName',
#        'TotalPopulation', 'TotalPopulationUrban', 'TotalPopulationRural',
#        'TotalPopulationMale', 'TotalPopulationMaleUrban',
#        'TotalPopulationMaleRural', 'TotalPopulationFemale',
#        'TotalPopulationFemaleUrban', 'TotalPopulationFemaleRural',
#        'NumberOfHouseholds', 'NumberOfHouseholdsUrban',
#        'NumberOfHouseholdsRural', 'LandAreaUrban', 'YearCode', 'Year',
#        'LandAreaRural', 'LandArea', 'LandAreaMappingError%',
#        'LandAreaUrbanMappingError%', 'LandAreaRuralMappingError%',
#        'TotalPopulationMappingError%', 'TotalPopulationUrbanMappingError%',
#        'TotalPopulationRuralMappingError%', 'TotalPopulationMaleMappingError%',
#        'TotalPopulationMaleUrbanMappingError%',
#        'TotalPopulationMaleRuralMappingError%',
#        'TotalPopulationFeMaleMappingError%',
#        'TotalPopulationFeMaleUrbanMappingError%',
# ...

# %%
df_metadata.head(5)
# Out:
#      VariableName VariableCode Type_Of_Variable Unit_Of_Measure
# 0         Country      Country   Key Identifier             NaN  \
# 1  State lgd code    StateCode   Key Identifier             NaN
# 2           State    StateName   Key Identifier             NaN
# 3        Yearcode     YearCode   Key Identifier             NaN
# 4            Year         Year   Key Identifier             NaN
#
#    Scaling_Factor Aggregation_Type Weighing_Varible_ID Weighing_Variable_Name
# 0               0              NaN                 NaN                    NaN  \
# 1               0              NaN                 NaN                    NaN
# 2               0              NaN                 NaN                    NaN
# 3               0              NaN                 NaN                    NaN
# 4               0              NaN                 NaN                    NaN
#
#   Long_Description
# 0          Country
# 1   State LGD Code
# 2            State
# 3         YearCode
# ...

# %%
df_source_data.head()
# Out:
#    srcStateName  srcYear  Cognizable crimes reported by IPC
# 0    D&N Haveli     2017                                266  \
# 1       Gujarat     2017                             128775
# 2           Goa     2017                               2965
# 3  Chhattisgarh     2017                              58481
# 4         Bihar     2017                             180573
#
#    Registered murder cases  Registered cases of offence against state
# 0                        3                                          0  \
# 1                      970                                         27
# 2                       31                                          6
# 3                      919                                         14
# 4                     2803                                        146
#
#    Cases reported under the Prevention of Corruption Act and related sections of IPC
# 0                                                  0                                  \
# ...

# %%
df_source_data.columns
# Out:
# Index(['srcStateName', 'srcYear', 'Cognizable crimes reported by IPC',
#        'Registered murder cases', 'Registered cases of offence against state',
#        'Cases reported under the Prevention of Corruption Act and related sections of IPC',
#        'Value of property stolen', 'Value of property recovered',
#        'Cases registered by Railway Protection Force',
#        'Registered cases of crime or atrocities against Scheduled Castes (SCs)',
#        'Registered cases of crime or atrocities against Scheduled Tribes (STs)',
#        'Cognizable crimes registered under SLL (Special & Local Laws).',
#        'Cognizable crimes registered under IPC (Indian Penal Code) and SLL (Special & Local Laws)',
#        'Cases registered under crime against women (including both IPC and SLL (Special & Local Laws crimes)',
#        'Cases of crime against foreigners', 'Registered cyber-crime cases',
#        'Cases registered under economic offences',
# ...

# %%
df_Ndap_report.head()
# Out:
#    Rowid Country  State lgd code              State  Yearcode
# 0      1   India               1  Jammu And Kashmir      2016  \
# 1      2   India               1  Jammu And Kashmir      2017
# 2      3   India               1  Jammu And Kashmir      2018
# 3      4   India               2   Himachal Pradesh      2016
# 4      5   India               2   Himachal Pradesh      2017
#
#                               Year  Cognizable crimes reported by ipc
# 0  Calendar Year (Jan - Dec), 2016                       23965.142177  \
# 1  Calendar Year (Jan - Dec), 2017                       22171.253325
# 2  Calendar Year (Jan - Dec), 2018                       23686.375371
# 3  Calendar Year (Jan - Dec), 2016                       13386.000000
# 4  Calendar Year (Jan - Dec), 2017                       13007.000000
#
#    Registered murder cases  Registered cases of offence against state
# 0               138.894339                                 180.953892  \
# ...

# %%
df_Ndap_report.columns
# Out:
# Index(['Rowid', 'Country', 'State lgd code', 'State', 'Yearcode', 'Year',
#        'Cognizable crimes reported by ipc', 'Registered murder cases',
#        'Registered cases of offence against state',
#        'Cases reported under the prevention of corruption act and related sections of ipc',
#        'Value of property stolen', 'Value of property recovered',
#        'Cases registered by railway protection force',
#        'Registered cases of crime or atrocities against scheduled castes (scs)',
#        'Registered cases of crime or atrocities against scheduled tribes (sts)',
#        'Cognizable crimes registered under sll (special & local laws).',
#        'Cognizable crimes registered under ipc (indian penal code) and sll (special & local laws)',
#        'Cases registered under crime against women (including both ipc and sll (special & local laws crimes)',
#        'Cases of crime against foreigners', 'Registered cyber-crime cases',
# ...

# %%
df_keys["srcStateName"].unique()
# Out:
# array(['Jammu & Kashmir', 'Himachal Pradesh', 'Punjab', 'Chandigarh',
#        'Uttarakhand', 'Haryana', 'Delhi', 'Rajasthan', 'Uttar Pradesh',
#        'Bihar', 'Sikkim', 'Arunachal Pradesh', 'Nagaland', 'Manipur',
#        'Mizoram', 'Tripura', 'Meghalaya', 'Assam', 'West Bengal',
#        'Jharkhand', 'Odisha', 'Chhattisgarh', 'Madhya Pradesh', 'Gujarat',
#        'Maharashtra', 'Andhra Pradesh', 'Karnataka', 'Goa', 'Lakshadweep',
#        'Kerala', 'Tamil Nadu', 'Puducherry', 'A&N Islands', 'Telangana',
#        'Daman & Diu', 'D&N Haveli'], dtype=object)

# %%
# I am analysising the data of five state only. Same can we done for other state also.
# Five states are Delhi,Bihar,Uttar Pradesh,Karnataka,West Bengal

# %%
df_keys.sort_values(by="srcYear",inplace = True)
df_Ndap_report.sort_values(by="Yearcode",inplace = True)
df_source_data.sort_values(by="srcYear",inplace = True)

# %%
def func_execute(dataframe,state,column):
    filt = dataframe["srcStateName"] == state
    df = dataframe[filt].loc[:,:]
    return df[column]

# %%
# Registered murder cases in the year of [2016,2017,2018] in State [Delhi,Bihar,Karnataka,West_Bengal,Uttar Pradesh]
#By Source Data

Bihar = list(func_execute(df_source_data,"Bihar","Registered murder cases"))
Delhi = list(func_execute(df_source_data,"Delhi","Registered murder cases"))
Uttar_Pradesh = list(func_execute(df_source_data,"Uttar Pradesh","Registered murder cases"))
Karnataka = list(func_execute(df_source_data,"Karnataka","Registered murder cases"))
West_Bengal = list(func_execute(df_source_data,"West Bengal","Registered murder cases"))

import matplotlib.pyplot as plt
fig,(ax1,ax2,ax3,ax4,ax5) = plt.subplots(nrows=5,ncols=1,figsize=(15,15))
ax1.pie(Bihar,labels =["2016","2017","2018"],shadow = True,autopct="%1.1f%%")
ax2.pie(Delhi,labels =["2016","2017","2018"],shadow = True,autopct="%1.1f%%")
ax3.pie(Uttar_Pradesh,labels =["2016","2017","2018"],shadow = True,autopct="%1.1f%%")
ax4.pie(Karnataka,labels =["2016","2017","2018"],shadow = True,autopct="%1.1f%%")
ax5.pie(West_Bengal,labels =["2016","2017","2018"],shadow = True,autopct="%1.1f%%")

ax1.set_xlabel("Bihar")
ax2.set_xlabel("Delhi")
ax3.set_xlabel("Uttar_Pradesh")
ax4.set_xlabel("Karnataka")
ax5.set_xlabel("West_Bengal")

plt.show()

# %%
def func_execute2(dataframe,state,column):
    filt = dataframe["State"] == state
    df = dataframe[filt].loc[:,:]
    return df[column]

# %%
# Registered murder cases in the year of [2016,2017,2018] in State [Delhi,Bihar,Karnataka,West_Bengal,Uttar Pradesh]
#By NDAP Report

Bihar = list(func_execute2(df_Ndap_report,"Bihar","Registered murder cases"))
Delhi = list(func_execute2(df_Ndap_report,"Delhi","Registered murder cases"))
Uttar_Pradesh = list(func_execute2(df_Ndap_report,"Uttar Pradesh","Registered murder cases"))
Karnataka = list(func_execute2(df_Ndap_report,"Karnataka","Registered murder cases"))
West_Bengal = list(func_execute2(df_Ndap_report,"West Bengal","Registered murder cases"))

import matplotlib.pyplot as plt
fig,(ax1,ax2,ax3,ax4,ax5) = plt.subplots(nrows=5,ncols=1,figsize=(15,15))
ax1.pie(Bihar,labels =["2016","2017","2018"],shadow = True,autopct="%1.1f%%")
ax2.pie(Delhi,labels =["2016","2017","2018"],shadow = True,autopct="%1.1f%%")
ax3.pie(Uttar_Pradesh,labels =["2016","2017","2018"],shadow = True,autopct="%1.1f%%")
ax4.pie(Karnataka,labels =["2016","2017","2018"],shadow = True,autopct="%1.1f%%")
ax5.pie(West_Bengal,labels =["2016","2017","2018"],shadow = True,autopct="%1.1f%%")

ax1.set_xlabel("Bihar")
ax2.set_xlabel("Delhi")
ax3.set_xlabel("Uttar_Pradesh")
ax4.set_xlabel("Karnataka")
ax5.set_xlabel("West_Bengal")

plt.show()

# %%
# Cases registered under crime against women (including both IPC and SLL (Special & Local Laws crimes) in the year of [2016,2017,2018] in State [Delhi,Bihar,Karnataka,West_Bengal,Uttar Pradesh]
#By Source Data

Bihar = list(func_execute(df_source_data,"Bihar",'Cases registered under crime against women (including both IPC and SLL (Special & Local Laws crimes)'))
Delhi = list(func_execute(df_source_data,"Delhi",'Cases registered under crime against women (including both IPC and SLL (Special & Local Laws crimes)'))
Uttar_Pradesh = list(func_execute(df_source_data,"Uttar Pradesh",'Cases registered under crime against women (including both IPC and SLL (Special & Local Laws crimes)'))
Karnataka = list(func_execute(df_source_data,"Karnataka",'Cases registered under crime against women (including both IPC and SLL (Special & Local Laws crimes)'))
West_Bengal = list(func_execute(df_source_data,"West Bengal",'Cases registered under crime against women (including both IPC and SLL (Special & Local Laws crimes)'))

import matplotlib.pyplot as plt
fig,(ax1,ax2,ax3,ax4,ax5) = plt.subplots(nrows=5,ncols=1,figsize=(15,15))
ax1.pie(Bihar,labels =["2016","2017","2018"],shadow = True,autopct="%1.1f%%")
ax2.pie(Delhi,labels =["2016","2017","2018"],shadow = True,autopct="%1.1f%%")
ax3.pie(Uttar_Pradesh,labels =["2016","2017","2018"],shadow = True,autopct="%1.1f%%")
ax4.pie(Karnataka,labels =["2016","2017","2018"],shadow = True,autopct="%1.1f%%")
ax5.pie(West_Bengal,labels =["2016","2017","2018"],shadow = True,autopct="%1.1f%%")

ax1.set_xlabel("Bihar")
ax2.set_xlabel("Delhi")
ax3.set_xlabel("Uttar_Pradesh")
ax4.set_xlabel("Karnataka")
ax5.set_xlabel("West_Bengal")

plt.show()

# %%
# 'Cases registered under crime against women (including both IPC and SLL (Special & Local Laws crimes)' in the year of [2016,2017,2018] in State [Delhi,Bihar,Karnataka,West_Bengal,Uttar Pradesh]
#By NDAP Report

Bihar = list(func_execute2(df_Ndap_report,"Bihar",'Cases registered under crime against women (including both ipc and sll (special & local laws crimes)'))
Delhi = list(func_execute2(df_Ndap_report,"Delhi",'Cases registered under crime against women (including both ipc and sll (special & local laws crimes)'))
Uttar_Pradesh = list(func_execute2(df_Ndap_report,"Uttar Pradesh",'Cases registered under crime against women (including both ipc and sll (special & local laws crimes)'))
Karnataka = list(func_execute2(df_Ndap_report,"Karnataka",'Cases registered under crime against women (including both ipc and sll (special & local laws crimes)'))
West_Bengal = list(func_execute2(df_Ndap_report,"West Bengal",'Cases registered under crime against women (including both ipc and sll (special & local laws crimes)'))

import matplotlib.pyplot as plt
fig,(ax1,ax2,ax3,ax4,ax5) = plt.subplots(nrows=5,ncols=1,figsize=(15,15))
ax1.pie(Bihar,labels =["2016","2017","2018"],shadow = True,autopct="%1.1f%%")
ax2.pie(Delhi,labels =["2016","2017","2018"],shadow = True,autopct="%1.1f%%")
ax3.pie(Uttar_Pradesh,labels =["2016","2017","2018"],shadow = True,autopct="%1.1f%%")
ax4.pie(Karnataka,labels =["2016","2017","2018"],shadow = True,autopct="%1.1f%%")
ax5.pie(West_Bengal,labels =["2016","2017","2018"],shadow = True,autopct="%1.1f%%")

ax1.set_xlabel("Bihar")
ax2.set_xlabel("Delhi")
ax3.set_xlabel("Uttar_Pradesh")
ax4.set_xlabel("Karnataka")
ax5.set_xlabel("West_Bengal")

plt.show()

# %%
#Value of property recovered in the year of [2016,2017,2018] in State [Delhi,Bihar,Karnataka,West_Bengal,Uttar Pradesh]
#By Source Data

Bihar = list(func_execute(df_source_data,"Bihar",'Value of property recovered'))
Delhi = list(func_execute(df_source_data,"Delhi",'Value of property recovered'))
Uttar_Pradesh = list(func_execute(df_source_data,"Uttar Pradesh",'Value of property recovered'))
Karnataka = list(func_execute(df_source_data,"Karnataka",'Value of property recovered'))
West_Bengal = list(func_execute(df_source_data,"West Bengal",'Value of property recovered'))



import matplotlib.pyplot as plt
fig,(ax1,ax2,ax3,ax4,ax5) = plt.subplots(nrows=5,ncols=1,figsize=(15,15))
ax1.pie(Bihar,labels =["2016","2017","2018"],shadow = True,autopct="%1.1f%%")
ax2.pie(Delhi,labels =["2016","2017","2018"],shadow = True,autopct="%1.1f%%")
ax3.pie(Uttar_Pradesh,labels =["2016","2017","2018"],shadow = True,autopct="%1.1f%%")
ax4.pie(Karnataka,labels =["2016","2017","2018"],shadow = True,autopct="%1.1f%%")
ax5.pie(West_Bengal,labels =["2016","2017","2018"],shadow = True,autopct="%1.1f%%")

ax1.set_xlabel("Bihar")
ax2.set_xlabel("Delhi")
ax3.set_xlabel("Uttar_Pradesh")
ax4.set_xlabel("Karnataka")
ax5.set_xlabel("West_Bengal")

plt.show()

# %%
#Value of property recovered in the year of [2016,2017,2018] in State [Delhi,Bihar,Karnataka,West_Bengal,Uttar Pradesh]
#By NDAP report Data

Bihar = list(func_execute2(df_Ndap_report,"Bihar",'Value of property recovered'))
Delhi = list(func_execute2(df_Ndap_report,"Delhi",'Value of property recovered'))
Uttar_Pradesh = list(func_execute2(df_Ndap_report,"Uttar Pradesh",'Value of property recovered'))
Karnataka = list(func_execute2(df_Ndap_report,"Karnataka",'Value of property recovered'))
West_Bengal = list(func_execute2(df_Ndap_report,"West Bengal",'Value of property recovered'))



import matplotlib.pyplot as plt
fig,(ax1,ax2,ax3,ax4,ax5) = plt.subplots(nrows=5,ncols=1,figsize=(15,15))
ax1.pie(Bihar,labels =["2016","2017","2018"],shadow = True,autopct="%1.1f%%")
ax2.pie(Delhi,labels =["2016","2017","2018"],shadow = True,autopct="%1.1f%%")
ax3.pie(Uttar_Pradesh,labels =["2016","2017","2018"],shadow = True,autopct="%1.1f%%")
ax4.pie(Karnataka,labels =["2016","2017","2018"],shadow = True,autopct="%1.1f%%")
ax5.pie(West_Bengal,labels =["2016","2017","2018"],shadow = True,autopct="%1.1f%%")

ax1.set_xlabel("Bihar")
ax2.set_xlabel("Delhi")
ax3.set_xlabel("Uttar_Pradesh")
ax4.set_xlabel("Karnataka")
ax5.set_xlabel("West_Bengal")

plt.show()
